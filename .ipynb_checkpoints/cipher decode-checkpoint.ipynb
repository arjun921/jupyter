# %%
s = "..."

# %%
lets = set()
totalCount = 0
for x in s:
    totalCount+=1
    lets.add(x)

# %%
# print("letter:count")
# occurences = []
dictt = {}
for x in lets:
    count = 0
    for y in s:
        if x==y:
            count+=1
#     ab = str("{}:{}".format(x,count))
    dictt[x] = count
# Out:
# letter:count

# %%
for x in lets:
    print(x,dictt[x]/totalCount)
# Out:
# E 0.033854166666666664
# A 0.06380208333333333
# D 0.019097222222222224
# B 0.038628472222222224
# J 0.027994791666666668
# G 0.0625
# F 0.03428819444444445
# H 0.038411458333333336
# O 0.026258680555555556
# I 0.027777777777777776
# N 0.025173611111111112
# K 0.04861111111111111
# Z 0.036675347222222224
# M 0.06488715277777778
# L 0.06336805555555555
# Q 0.024956597222222224
# T 0.05360243055555555
# R 0.013671875
# S 0.03342013888888889
# W 0.06727430555555555
# X 0.056206597222222224
# U 0.026041666666666668
# C 0.018229166666666668
# P 0.030815972222222224
# Y 0.01953125
# V 0.044921875
